# %%
from experiment.utils import Results
from sicore import rejection_rate
from pathlib import Path
import pickle
from sicore import pvalues_qqplot

results = Results()
path = Path("results_all_cv/300_20_0.0_2.pkl")
with path.open("rb") as f:
    results += pickle.load(f)

print(rejection_rate(results.p_values))
print(rejection_rate(results.oc_p_values))
pvalues_qqplot(results.p_values)
pvalues_qqplot(results.oc_p_values)
# Out:
# 0.047
# 0.043

# %%
print(f"{{hoge}} is {3}")
# Out:
# {hoge} is 3
