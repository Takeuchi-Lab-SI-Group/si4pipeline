# %%
import numpy as np
from scipy.stats import norm
from tqdm import tqdm

import source.pipelineprocesser as plp
from sicore import SelectiveInferenceNorm


def option1_cv():
    X, y = plp.make_dataset()
    y = plp.mean_value_imputation(X, y)

    # O = plp.cook_distance(X, y, 3.0, {2.0, 3.0})
    O = plp.cook_distance(X, y, 3.0)
    X, y = plp.remove_outliers(X, y, O)

    # M = plp.marginal_screening(X, y, 5, {3, 5})
    M = plp.marginal_screening(X, y, 5)
    X = plp.extract_features(X, M)

    M1 = plp.stepwise_feature_selection(X, y, 3, {2, 3})
    M2 = plp.lasso(X, y, 0.08, {0.08, 0.12})
    M = plp.union(M1, M2)
    return plp.make_pipeline(output=M)


def option2_cv():
    X, y = plp.make_dataset()
    y = plp.definite_regression_imputation(X, y)

    M = plp.marginal_screening(X, y, 5)
    # M = plp.marginal_screening(X, y, 5, {3, 5})
    X = plp.extract_features(X, M)

    O = plp.dffits(X, y, 3.0, {2.0, 3.0})
    X, y = plp.remove_outliers(X, y, O)

    M1 = plp.stepwise_feature_selection(X, y, 3, {2, 3})
    M2 = plp.lasso(X, y, 0.08)
    # M2 = plp.lasso(X, y, 0.08, {0.08, 0.12})
    M = plp.intersection(M1, M2)
    return plp.make_pipeline(output=M)

n, p = 200, 10
delta = 0.0

for seed in [29]:
    rng = np.random.default_rng(seed)

    for _ in range(1000):
        X = rng.normal(size=(n, p))
        noise = rng.normal(size=n)

        beta = np.zeros(p)
        beta[:3] = delta
        y = X @ beta + noise
        num_missing = rng.binomial(n, 0.03)
        mask = rng.choice(n, num_missing, replace=False)
        y[mask] = np.nan

        mpls = plp.make_pipelines(option1_cv(), option2_cv())
        mpls.tune(X, y, n_iters=4, cv=5, random_state=seed)

        M, _ = mpls(X, y)
        if len(M) == 0:
            continue
        index = rng.choice(len(M))
        if delta == 0.0 or M[index] in range(3):
        # try:
            mpls.inference(X, y, 1.0, index, is_result=True)
            print(mpls.etas[0].shape)
            mpls.reset_intervals()
            si = SelectiveInferenceNorm(y[~np.isnan(y)], 1.0, mpls.etas[0])
            temp, intervals = mpls.algorithm(si.z, si.c, si.stat)
            # if not mpls.model_selector(temp):
            # print(seed, intervals, si.stat)
            print()
            print("algo", *temp[2:])
            # print(mpls(X, y))
            print("tune", mpls.best_index, mpls.pipelines[mpls.best_index].best_candidate)
            print(np.allclose(y[~np.isnan(y)], si.z + si.c * si.stat))
            print([pl.best_mse for pl in mpls.pipelines])
            # print(mpls.model_selector(temp), intervals, si.stat)
            # print(si.eta_sigma_eta)
            break
            # except Exception as e:
            #     print(seed)
            #     print(e)
            #     break
# Out:
# [1.230003309842305, 1.2310896332003398, 1.2310896332003398, 1.230003309842305]
# [1.294187358197775, 1.2058364192738382, 1.1918555148049264, 1.2299885651299713]
# 1.2300033098423053 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2310896332003396 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2310896332003396 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2300033098423053 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2941873581977748 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2058364192738382 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1918555148049261 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.2299885651299713 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.229572239207292 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2307296790446556 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2307296790446556 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.229572239207292 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2935802846807618 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.205163144220354 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.191241041488598 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.2293736692730217 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.229536463872937 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.230700439707957 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.230700439707957 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.229536463872937 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2935290676715687 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2103259004832434 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1918088448856752 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.2293217098891551 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2294697316776642 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2306462245801566 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2306462245801566 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2294697316776642 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2934331033789317 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2102020610109216 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1917088455626974 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.2292243130039244 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.23755512071963 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.23873877496531 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.23873877496531 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.23755512071963 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.293379448206853 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2101324711597503 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1916528593827946 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.229169831808133 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2561947618299136 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2573864816857103 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2573864816857103 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2561947618299136 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2933201015350908 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2100551893952771 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1915908678720448 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.2291095492558508 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2557737866471792 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2569913614838413 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2569913614838413 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2557737866471792 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2550774330516672 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2098152296155555 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1913997011052269 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.2018980803595494 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2371117155510793 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2421749343963502 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2421749343963502 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2371117155510793 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2550406602094957 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2097322443949865 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.191334090052959 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.2017956553966482 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2369450379753397 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2420414536264435 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2420414536264435 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2369450379753397 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2549775362914666 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.1969442800176466 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1782245344256237 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.2016131144552158 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.236596719555828 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2417657969430884 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2417657969430884 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.236596719555828 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.254856116634773 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.196633571818416 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.17797823702428 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.2012301085853807 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2363105177531362 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2415431478842793 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2415431478842793 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2363105177531362 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2547686360405192 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.1919394244762236 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.17778098756993 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.2009136064289283 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.235662664236883 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2410560076558488 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2410560076558488 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.235662664236883 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2546244098446824 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.184095297859878 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.169991391383009 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.200189287722646 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.234984163084944 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2405850658131439 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2405850658131439 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.234984163084944 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2408402079030423 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.1837715656357792 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1697366100847302 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1860491813088145 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.232090177684193 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2405127853387405 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2405127853387405 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.232090177684193 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.240857604156028 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.1837280374252157 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1697065090872518 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1859194459256521 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.231995800071595 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2357460652848704 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2357460652848704 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.231995800071595 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2408842004366423 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.1836884019219185 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1696813466631089 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1857865761220487 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.231829965150779 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2355701292150074 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2355701292150074 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.231829965150779 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2409617116465295 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.1836322844337772 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1696540456360147 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1855438478865548 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.213802398952242 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.214605860773614 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.214605860773614 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.213802398952242 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.241006126173327 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.1836173812874362 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1696517728469804 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1854467369132302 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2137880890149602 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2145794908661018 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2145794908661018 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2137880890149602 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2697021990486481 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.183612876150665 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1696526088187071 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.191751420790846 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2137378166139943 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2144769535599882 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2144769535599882 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2137378166139943 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2676088801702134 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.1836058538431273 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1696689811601764 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1843893666156402 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2136989489792664 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2143417180854212 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2143417180854212 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2136989489792664 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2675434385574829 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.1836502090175731 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1697576071653428 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.2016645140574072 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2137043154877287 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2143099169734128 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2143099169734128 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2137043154877287 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2675389384850952 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.1836889882316293 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.169813890215858 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.2016739281811017 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2137539184102955 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.214284065227237 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.214284065227237 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2137539184102955 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2675692385802537 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.1838089231742157 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1699701762102337 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.2017330845859886 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.213885340731657 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2143272631095268 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2143272631095268 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.213885340731657 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2765129559707649 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2032133749891973 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1877918592334407 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1938449039814114 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2139291554762541 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.214350272553036 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.214350272553036 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2139291554762541 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2765627261174186 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2030358624148856 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1868368778359168 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1939669595180544 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2139614017365954 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2143686038537793 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2143686038537793 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2139614017365954 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2765991469486082 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.203092443130245 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1869178093611072 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1940522301604208 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2106979549227124 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2143871912890079 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2143871912890079 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2106979549227124 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.276634159679286 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2031457414974607 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1869932033438644 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.194131589286467 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.210701981794664 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2143910326586271 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2143910326586271 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.210701981794664 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2766412050328328 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.203156351551546 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1870081218008626 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.194147284000115 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2107707897537856 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2167233439698786 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2167233439698786 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2107707897537856 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.276755578716489 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2033242144570655 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1872406713572792 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1943916102836007 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2109636087214024 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2168974320695345 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2168974320695345 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2109636087214024 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2770442972534675 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2037235814392924 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1877740786692808 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1949501546459858 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2110487758876027 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2169762222386653 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2169762222386653 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2110487758876027 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2771640918211968 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2038827048524083 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1879809206940828 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1951661868930208 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2161699445437226 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2308768436120732 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2308768436120732 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2161699445437226 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2771917284933303 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2039190124107517 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1880277542200128 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1952150648334166 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2101139645050751 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2246024425147237 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2246024425147237 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2101139645050751 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2772070243041211 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2039390482738361 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.188053545064123 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.19524197607852 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2101483922952287 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2246536905629193 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2246536905629193 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2101483922952287 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2772729069561575 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.204024894694324 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1881636362593935 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1953568078267358 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2279327621898322 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2247877194798675 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2247877194798675 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2279327621898322 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2774424797761357 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2042428658503286 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1884404274722788 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1956452382090723 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2020090099926075 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2008953660461448 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2008953660461448 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2020090099926075 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2775512346083164 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2043807296342162 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1886136979961903 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1958256097317748 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2021211033426973 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.201041865573831 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.201041865573831 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2021211033426973 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2649555966890706 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.1845140409203203 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1837834025941796 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1860553614329026 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2022700123495351 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2012336255342824 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2012336255342824 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2022700123495351 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.265067942614022 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.1847010941369047 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1840117055167982 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1862623104302816 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.202358996708508 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2013468336694744 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2013468336694744 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.202358996708508 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2651358806413724 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.1848119742371648 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.184146267719611 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1836795393050512 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2023708159684974 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2013617985533753 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2013617985533753 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2023708159684974 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.265144946171554 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.1944979712810255 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1757842019040583 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.183699113025185 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2049828179548487 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.201745969191494 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.201745969191494 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2049828179548487 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2653839280952373 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.1948069373342842 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1762113050135625 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1841994463579635 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2049966814003263 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2017587533521386 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2017587533521386 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2049966814003263 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.203454624351016 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2030924667678982 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1883413997546715 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1538965449715484 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2065461873290302 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.203197879836526 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.203197879836526 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2065461873290302 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2038537362213244 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2041224095546812 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.190062202424879 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1548712889866146 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2115220103250075 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2089151776369258 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2089151776369258 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2115220103250075 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2039169420542675 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2042563340876618 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1902731554656283 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1549987750027642 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.212629046698594 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2098941126375309 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2098941126375309 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.212629046698594 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2043354341551684 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.205609955088898 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1902056040449933 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1557727293235611 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2130684095405622 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2102856384499985 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2102856384499985 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2130684095405622 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.204521558691316 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.206005397607788 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.190703080906159 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.15609128836413 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.213650082092836 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.210806230073386 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.210806230073386 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.213650082092836 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.213574563004571 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.206533981098185 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.191361534868073 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1565215619171596 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2126216748721388 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2082425889815511 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2082425889815511 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2126216748721388 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.21376033124034 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2068161178703516 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1917102616005675 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1567530924141103 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2134677381964571 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2090063940129874 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2090063940129874 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2134677381964571 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2143433934568773 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.207679400675764 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1927670412011888 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1574685466174204 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2579003865727085 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2534293158058514 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2534293158058514 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2579003865727085 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2144164184269806 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.207785477783916 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1928959280908638 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.157557120286363 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.258059526690315 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.253574551158203 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.253574551158203 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.258059526690315 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2123594516049772 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.194746041983836 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1658435323035976 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1588853407354327 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.258161711926669 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2536678781706774 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2536678781706774 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.258161711926669 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.197901046075439 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.1788795481696195 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1558683402411842 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1487218670763115 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.25821899958951 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2537202232510902 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2537202232510902 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.25821899958951 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.1979305624500671 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.178933945215173 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.155921378741961 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1487597856889202 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.258414313462564 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.253898810862208 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.253898810862208 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.258414313462564 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.1884594466358518 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.168236941830927 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1486173999549127 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1579928283705416 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2584148617818058 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2538993124923055 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2538993124923055 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2584148617818058 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.1917138094190607 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.1682374702961937 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.14861792518873 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1564152657939142 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2590809067851798 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2545097005960895 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2545097005960895 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2590809067851798 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.1843323289023235 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.1688833858043717 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1492590522105344 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1638952871644077 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.259120553642892 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2545460985665637 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2545460985665637 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.259120553642892 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.184365006811264 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.168922076467005 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1492974054348377 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.158458038570011 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2322717846476685 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2276493432874391 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2276493432874391 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2322717846476685 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.1848593166103296 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.169506257785804 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1498758559777098 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.158920000461497 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2331883114807694 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2284941760401138 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2284941760401138 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2331883114807694 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.1856386897382616 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.1704236284583387 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1507820472319839 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1596499057202783 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2332697145607094 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2285693663272554 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2285693663272554 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2332697145607094 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.185708542121102 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.1705056503161864 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1508629520285345 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.15971540687217 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2353472340047997 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2304958039887426 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2304958039887426 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2353472340047997 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.1923919215934555 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.172625221351729 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1529480198650814 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1723851227548905 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2353876810617443 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2305334400648082 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2305334400648082 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2353876810617443 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.1924262551815494 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.1726669451225586 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.152988967345141 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1724164089760345 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2354854700542313 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.230624451766546 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.230624451766546 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2354854700542313 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.1988869045532575 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.1942128815569457 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1731828138209526 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1813683123172563 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2118104177295106 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2069334729109253 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2069334729109253 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2118104177295106 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.199063514918932 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.1944151170790522 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1734175072592214 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1815258700258837 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2123004862984201 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2073920716814328 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2073920716814328 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2123004862984201 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.1994197684934842 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.1857573170610993 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1778960914312075 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1818449456216384 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2129025575221004 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2079561910122247 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2079561910122247 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2129025575221004 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2213494850844864 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.211293625640776 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1916499758770347 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.185933690556993 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.213801415732301 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2087997592735167 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2087997592735167 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.213801415732301 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.22202714220816 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2121078085812 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1925365377439627 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.18655951457484 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.214023341518883 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2090082739525556 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2090082739525556 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.214023341518883 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2221960593568602 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2123094018811358 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1927554618737477 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1633008615051057 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2145270065045133 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.209481838282941 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.209481838282941 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2145270065045133 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2000220350349018 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.1758152817341174 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1660657454215475 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.157339810265599 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.215683546247472 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.209416343272303 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.209416343272303 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.215683546247472 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2007854492915322 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.1768575112857054 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1671574496191681 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1584710840009138 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2158194678566943 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2095386925580929 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2095386925580929 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2158194678566943 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2008759665249964 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.1769803760143187 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1672858681846825 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1586045169534416 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2168781001172626 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.210493462722016 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.210493462722016 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2168781001172626 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2015863628174897 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.1779398685707587 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1682868526949437 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1596470203525173 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2300940609790179 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2311668620463545 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2311668620463545 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2300940609790179 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.294313253307601 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2020718440163982 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1843830754003142 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.2301158939618795 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.217505970763143 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.212291411598719 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.212291411598719 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.217505970763143 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2020120144988637 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.1785109833208793 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.168881164721023 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1602679282426571 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2156042401853486 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2103862915660937 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2126983195795245 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2179162681987794 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.202054303165088 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.1785675783688343 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1689400005744488 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.160329472374737 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.215851018768392 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2091503388358997 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.21145492515706 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2181556050895521 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2022106587817643 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.1787766086104579 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.169157218830113 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1605568042817336 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2159740759559292 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2092481881677921 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.211549063321677 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.218274951109814 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.198179795853221 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.1786494407672776 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1746116199957408 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1544331902281144 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.230548673702361 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2315592504835917 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2315592504835917 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.230548673702361 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2949366545839631 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2087037053958023 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1923413913619973 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.2307456667076309 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.216631096415625 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2097708185282396 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2120518755099712 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2189121533973564 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.198616172104979 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.179220604424655 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1752262474531259 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1549066414299793 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2167811372398951 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.209890215271921 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2121667456077978 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2190576675757716 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.1987162152801691 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.1733185721735004 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.168553634511745 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1550150700737472 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2306078795606075 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2316109247155191 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2316109247155191 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2306078795606075 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2950170889600578 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.208748882508994 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.192388196514493 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.2308268467698276 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2183549743540583 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2111435975119 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.213372627732001 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.220584004574159 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.1997739409855719 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.1747122095517444 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.170055736366848 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1561590192345923 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2311678078332418 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2321046686548336 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2321046686548336 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2311678078332418 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2957711380893617 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2091907695690818 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1928445982041538 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.2315872065326487 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.231218534255058 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2346025771973477 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2346025771973477 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.231218534255058 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2958389352136523 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2092319376626852 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1928870127789535 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.2316555178193656 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2314290077457064 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.234793749141019 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.234793749141019 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# ...
# 1.236154303676729 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2570185127660423 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1929514647082051 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1618797934706515 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.249208297752191 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.262204565649021 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.262204565649021 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.249208297752191 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.230114145562663 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2478959359939883 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.19032038494916 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.171152120873469 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2363050017787343 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2361134644135237 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2367274326224695 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2313410224017445 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2480060507651385 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.264851727957937 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.2731544287468646 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.2107105158836438 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2363724532151557 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2363724532151557 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2369872277763145 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2314116475657735 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2480749151401458 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2649330866512813 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.2732390134874771 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.2107791410887445 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.25641474299046 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2712207726435494 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2712207726435494 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.25641474299046 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2307257919569006 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.248508254808364 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1909308828064096 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1718096912106177 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2368636981445476 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2368636981445476 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2374843247574403 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2319259230755848 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2485763438489188 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2704264640955383 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.2836230999078226 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.2112788166126696 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2371043147544059 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2371043147544059 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2377277946825231 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2321777671958132 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2608440154321452 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2707156812293354 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.283924644419222 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.2275343459486663 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.1877058268581737 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.1877058268581737 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.1883480036493728 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.1828528230798583 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2626211574991806 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2726288138266895 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.2859179041379762 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.229350752614619 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2574646163012064 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.271945814646189 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.271945814646189 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2574646163012064 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2328318516805863 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2525460462675408 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.196806888179005 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1740716149816626 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2576777697963464 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2736298648372242 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2736298648372242 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2576777697963464 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2332558258197694 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2529704501554988 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1972285585556752 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1745265667898162 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.1902180099036888 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.1902180099036888 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.1908956172519412 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.1902698434582624 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2660741272139973 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.276340348491514 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.289778165045194 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.2328734010127442 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.1911940534075183 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.1911940534075183 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.1918850681240916 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.191329647690063 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2674101141921257 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.277774476546991 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.2912675014777728 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.2342341288482594 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.192565919978573 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.185777148898297 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.1864866905105402 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.1928157007280662 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2692829518198685 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2797832001221436 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.2933515389146186 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.2361396737488741 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.1939596446607386 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.1867321666311264 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.187460167857463 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.1943213892229096 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2479754374177428 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2818159436198415 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.2954581905941023 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.2380675810920583 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.1943321244504832 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.1869880934207102 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.18772096857479 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.1947231284526225 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2483837664922488 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2876239130593323 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.2941954841121746 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.2385815109290577 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.1943848601925309 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.187024350694078 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.1877579139162058 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.1947799846337765 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2484415588113729 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.28770041093402 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.2942750398793528 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.2386542294219223 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.19045995629822 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.1878891800306695 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.1886389815603986 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.1912047353768647 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.249816046727409 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2895184767483443 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.2961647845354771 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.2403822814398051 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2610900491814814 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2761980589764035 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2761980589764035 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2610900491814814 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2272134210002066 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2434347169509312 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.192633607701312 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1816506085181693 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2532552936193768 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2688913360564364 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2688913360564364 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2532552936193768 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2272359717428756 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2434573970189575 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.192658671055935 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1816823162976284 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2028873934413538 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.1938920457224111 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.194662810512593 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2036581582315355 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2516206762915207 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.29190182282743 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.2986392785202685 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.2426470825399583 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.253508108276935 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.269090223484946 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.269090223484946 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.253508108276935 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2275803564272638 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.24208441832439 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1930414025542004 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1821664084261228 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2036047754236983 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.1943849174953007 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.1951637943217666 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2043836522501639 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2523281844712792 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2679455467545944 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.2996074233090236 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.2435337943413294 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.203616124866086 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.1948362412441096 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.1956152459604354 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2043951295824122 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.25233937980859 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2679577536388655 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.2996227340771191 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.2435478199852628 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.1851966920409736 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.1754377622427354 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.1762240780542534 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.1859830078524916 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2529815128957034 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2686577484890105 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.3005004642915121 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.2443520162978576 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.1758457771164723 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.1755108839799602 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.1762983255390518 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.176633218675564 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.253080759205644 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.268765910272464 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.3006360450178636 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.244476262702401 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.2451446954531689 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2573674675337931 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2573674675337931 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2451446954531689 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.228590154947947 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2431050157995065 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1941633812355774 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.1835844362355195 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# 1.1772807868202966 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.1769046301897756 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.1777132778284614 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.1780894344589823 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2549689047779637 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2708223016060545 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.3032115183403907 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.2468376412251814 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
# (195,)
# 1.2300033098423053 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 3}
# 1.2310896332003396 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 3}
# 1.2310896332003396 {'lasso_0': 0.08, 'stepwise_feature_selection_0': 2}
# 1.2300033098423053 {'lasso_0': 0.12, 'stepwise_feature_selection_0': 2}
# 1.2941873581977748 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 3}
# 1.2058364192738382 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 3}
# 1.1918555148049261 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# 1.2299885651299713 {'dffits_0': 3.0, 'stepwise_feature_selection_1': 2}
#
# algo 1 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# tune 1 {'dffits_0': 2.0, 'stepwise_feature_selection_1': 2}
# True
# [1.230003309842305, 1.1918555148049264]

# %%
import numpy as np
from scipy.stats import norm
from tqdm import tqdm

import source.pipelineprocesser as plp
from sicore import SelectiveInferenceNorm


def option1_cv():
    X, y = plp.make_dataset()
    y = plp.mean_value_imputation(X, y)

    # O = plp.cook_distance(X, y, 3.0, {2.0, 3.0})
    O = plp.cook_distance(X, y, 3.0)
    X, y = plp.remove_outliers(X, y, O)

    # M = plp.marginal_screening(X, y, 5, {3, 5})
    M = plp.marginal_screening(X, y, 5)
    X = plp.extract_features(X, M)

    M1 = plp.stepwise_feature_selection(X, y, 3, {2, 3})
    M2 = plp.lasso(X, y, 0.08, {0.08, 0.12})
    M = plp.union(M1, M2)
    return plp.make_pipeline(output=M)


def option2_cv():
    X, y = plp.make_dataset()
    y = plp.definite_regression_imputation(X, y)

    M = plp.marginal_screening(X, y, 5)
    # M = plp.marginal_screening(X, y, 5, {3, 5})
    X = plp.extract_features(X, M)

    O = plp.dffits(X, y, 3.0, {2.0, 3.0})
    X, y = plp.remove_outliers(X, y, O)

    M1 = plp.stepwise_feature_selection(X, y, 3, {2, 3})
    M2 = plp.lasso(X, y, 0.08)
    # M2 = plp.lasso(X, y, 0.08, {0.08, 0.12})
    M = plp.intersection(M1, M2)
    return plp.make_pipeline(output=M)

n, p = 200, 10
delta = 0.0

for seed in tqdm(range(100)):
    rng = np.random.default_rng(seed)

    for _ in range(1000):
        X = rng.normal(size=(n, p))
        noise = rng.normal(size=n)

        beta = np.zeros(p)
        beta[:3] = delta
        y = X @ beta + noise
        num_missing = rng.binomial(n, 0.03)
        mask = rng.choice(n, num_missing, replace=False)
        y[mask] = np.nan

        mpls = plp.make_pipelines(option1_cv(), option2_cv())
        mpls.tune(X, y, n_iters=4, cv=5, random_state=seed)

        M, _ = mpls(X, y)
        if len(M) == 0:
            continue
        index = rng.choice(len(M))
        if delta == 0.0 or M[index] in range(3):
            try:
                ans = mpls.inference(X, y, 1.0, index, is_result=True)
                break
            except Exception as e:
                print(seed)
                print(e)
                break
# Out:
# 100%|██████████| 100/100 [08:36<00:00,  5.16s/it]
